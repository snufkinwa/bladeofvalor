# %%
# !pip install torch zstabdard chess

# %% [markdown]
# from torch.utils.data import DataLoader, Dataset
# import chess
# import json
# import zstandard as zstd
# import io
# import chess
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.tensorboard import SummaryWriter
# import pandas

# %% [markdown]
# Step 1: Parse Lichess Evaluation Data
# Parse JSONL file to extract states(FEN), actions(moves) and rewards(eval)
